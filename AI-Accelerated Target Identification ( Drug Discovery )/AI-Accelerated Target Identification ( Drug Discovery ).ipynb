# %% [markdown]
# Retrieve all the approved drugs from ChEMBL as well as the date of approval and the SMILES.

# %%
# !pip install datamol
# !pip install chembl_webresource_client
# Out:
# Collecting datamol
#   Downloading datamol-0.12.5-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from datamol) (4.66.5)
# Collecting loguru (from datamol)
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from datamol) (1.4.2)
# Requirement already satisfied: fsspec>=2021.9 in /usr/local/lib/python3.10/dist-packages (from datamol) (2024.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datamol) (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from datamol) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datamol) (10.4.0)
# Collecting selfies (from datamol)
#   Downloading selfies-2.1.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from datamol) (4.3.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from datamol) (1.5.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datamol) (24.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from datamol) (4.12.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from datamol) (6.4.5)
# Collecting rdkit (from datamol)
#   Downloading rdkit-2024.3.5-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datamol) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datamol) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->datamol) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->datamol) (1.16.0)
# Downloading datamol-0.12.5-py3-none-any.whl (495 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.4/495.4 kB 3.2 MB/s eta 0:00:00
# Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 2.8 MB/s eta 0:00:00
# Downloading rdkit-2024.3.5-cp310-cp310-manylinux_2_28_x86_64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 12.0 MB/s eta 0:00:00
# Downloading selfies-2.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: selfies, rdkit, loguru, datamol
# Successfully installed datamol-0.12.5 loguru-0.7.2 rdkit-2024.3.5 selfies-2.1.2
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.8.30)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 801.1 kB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 1.9 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.6 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.2 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %%
pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.10/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.8.30)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.2.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)

# %%
import pandas as pd
import datamol as dm

from chembl_webresource_client.new_client import new_client as client

# %%
# First, we retrieve the ChEMBL IDs for all the approved drugs (max_phase=4)
mol_ids = client.molecule.filter(max_phase=4).only(["molecule_chembl_id"])
mol_ids = pd.DataFrame(mol_ids)

len(mol_ids)
# Out:
# 4384

# %%
# Now retrieve other columns of interest

columns = ["molecule_chembl_id", "pref_name", "first_approval", "molecule_structures", "molecule_type"]


def _get_mol(molecule_chembl_id):
    mols = client.molecule.filter(molecule_chembl_id=molecule_chembl_id).only(columns)
    assert len(mols) == 1
    mol = mols[0]

    if mol.get("molecule_structures") is not None and "canonical_smiles" in mol.get(
        "molecule_structures", []
    ):
        mol["smiles"] = mol["molecule_structures"]["canonical_smiles"]

    if "molecule_structures" in mol:
        del mol["molecule_structures"]

    return pd.Series(mol)


mols = dm.parallelized(
    _get_mol,
    mol_ids["molecule_chembl_id"],
    n_jobs=256,
    scheduler="threads",
    progress=True,
)
mols = pd.DataFrame(mols)

mols.head()
# Out:
#   0%|          | 0/4384 [00:00<?, ?it/s]
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001153111616; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000934901312; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000993650240; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000884545088; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000859366976; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000951686720; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000909723200; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001387591232; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001085969984; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000800618048; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000809010752; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000834188864; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000985257536; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001010435648; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001169897024; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001119540800; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000120809024; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001102755392; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001035613760; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000892937792; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000968472128; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000691512896; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000943294016; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000783832640; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000725083712; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000683120192; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000699905600; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000674727488; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000842581568; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000960079424; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001161504320; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000708298304; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000607585856; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000775439936; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000741869120; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000632763968; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000456517184; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001136326208; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000792225344; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000850974272; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001421162048; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001127933504; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000926508608; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001094362688; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000624371264; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000590800448; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000481695296; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000498480704; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000733476416; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000557229632; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001002042944; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000271877696; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000288663104; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000523658816; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000439731776; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000750261824; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000540444224; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000565622336; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000464909888; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001027221056; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000615978560; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000515266112; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000657942080; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000422946368; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000389375552; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000095630912; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000255092288; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000179557952; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000380982848; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 139999936169536; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000414553664; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000305448512; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000020096576; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000280270400; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000330626624; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000229914176; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 139999810278976; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000062060096; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000112416320; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 139999952954944; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000313841216; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 139999843849792; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000011703872; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000221521472; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 139999961347648; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 139999910991424; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000036881984; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000238306880; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 139999508141632; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 139999944562240; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001111148096; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 139999617246784; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000355804736; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140001044006464; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 139
retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 140000179557952; retrying (1/3)
# WARNING:requests_cache.backends.sqlite:Database is locked in thread 139999214396992; retrying (2/3)
#    first_approval molecule_chembl_id   molecule_type       pref_name  \
# 0          1976.0            CHEMBL2  Small molecule        PRAZOSIN
# 1          1984.0            CHEMBL3  Small molecule        NICOTINE
# 2          1990.0            CHEMBL4  Small molecule       OFLOXACIN
# 3          1964.0            CHEMBL5  Small molecule  NALIDIXIC ACID
# 4          1965.0            CHEMBL6  Small molecule    INDOMETHACIN
#
#                                              smiles
# 0     COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC
# 1                              CN1CCC[C@H]1c1cccnc1
# 2  CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 3                   CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 4    COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1

# %%
# Let's focus on small molecules with a valid SMILES and a first approval date
mols = mols.query("molecule_type == 'Small molecule' & smiles.notna() & first_approval.notna()")
mols = mols.reset_index(drop=True)

mols
# Out:
#       first_approval molecule_chembl_id   molecule_type  \
# 0             1976.0            CHEMBL2  Small molecule
# 1             1984.0            CHEMBL3  Small molecule
# 2             1990.0            CHEMBL4  Small molecule
# 3             1964.0            CHEMBL5  Small molecule
# 4             1965.0            CHEMBL6  Small molecule
# ...              ...                ...             ...
# 2771          2021.0      CHEMBL5315120  Small molecule
# 2772          2018.0      CHEMBL5315121  Small molecule
# 2773          2015.0      CHEMBL5315122  Small molecule
# 2774          1996.0      CHEMBL5315124  Small molecule
# 2775          2018.0      CHEMBL5315125  Small molecule
#
#                      pref_name  \
# 0                     PRAZOSIN
# 1                     NICOTINE
# 2                    OFLOXACIN
# 3               NALIDIXIC ACID
# 4                 INDOMETHACIN
# ...                        ...
# 2771  ODEVIXIBAT SESQUIHYDRATE
# 2772   TECOVIRIMAT MONOHYDRATE
# 2773     BORTEZOMIB D-MANNITOL
# 2774              LEVOFLOXACIN
# 2775     DUVELISIB MONOHYDRATE
#
#                                                  smiles
# 0         COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC
# 1                                  CN1CCC[C@H]1c1cccnc1
# 2      CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23
# 3                       CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 4        COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1
# ...                                                 ...
# 2771  CCCCC1(CCCC)CN(c2ccccc2)c2cc(SC)c(OCC(=O)N[C@@...
# 2772  O.O=C(NN1C(=O)[C@@H]2[C@@H]3C=C[C@@H]([C@H]4C[...
# 2773  CC(C)C[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)c1cncc...
# 2774  C[C@H]1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)...
# 2775  C[C@H](Nc1ncnc2nc[nH]c12)c1cc2cccc(Cl)c2c(=O)n...
#
# [2776 rows x 5 columns]

# %%
# !pip install gradio cohere
# Out:
# Collecting gradio
#   Downloading gradio-4.44.0-py3-none-any.whl.metadata (15 kB)
# Collecting cohere
#   Downloading cohere-5.9.4-py3-none-any.whl.metadata (3.4 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Collecting fastapi<1.0 (from gradio)
#   Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.3.0 (from gradio)
#   Downloading gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx>=0.24.1 (from gradio)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.24.7)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.4.5)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.26.4)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.4)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.9.2)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.10-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.2)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.6.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.2.3)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.3.0->gradio) (2024.6.1)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.3.0->gradio)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting boto3<2.0.0,>=1.34.0 (from cohere)
#   Downloading boto3-1.35.25-py3-none-any.whl.metadata (6.6 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere)
#   Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting httpx-sse==0.4.0 (from cohere)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting parameterized<0.10.0,>=0.9.0 (from cohere)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.23.4)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.32.3)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.19.1)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere)
#   Downloading types_requests-2.32.0.20240914-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Collecting botocore<1.36.0,>=1.35.25 (from boto3<2.0.0,>=1.34.0->cohere)
#   Downloading botocore-1.35.25-py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.34.0->cohere)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2.0.0,>=1.34.0->cohere)
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi<1.0->gradio)
#   Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio) (3.16.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio) (4.66.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (3.3.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (13.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-4.44.0-py3-none-any.whl (18.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 48.0 MB/s eta 0:00:00
# Downloading gradio_client-1.3.0-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 23.6 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading cohere-5.9.4-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.1/233.1 kB 17.9 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading boto3-1.35.25-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 12.4 MB/s eta 0:00:00
# Downloading fastapi-0.115.0-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 7.7 MB/s eta 0:00:00
# Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 56.2 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.0 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.5 MB/s eta 0:00:00
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 12.2 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading python_multipart-0.0.10-py3-none-any.whl (22 kB)
# Downloading ruff-0.6.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 36.2 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading types_requests-2.32.0.20240914-py3-none-any.whl (15 kB)
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.9 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading botocore-1.35.25-py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 54.3 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.9 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 6.1 MB/s eta 0:00:00
# Downloading starlette-0.38.6-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.2 MB/s eta 0:00:00
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: pydub, websockets, types-requests, tomlkit, semantic-version, ruff, python-multipart, parameterized, orjson, jmespath, httpx-sse, h11, ffmpy, fastavro, aiofiles, uvicorn, starlette, httpcore, botocore, s3transfer, httpx, fastapi, gradio-client, boto3, gradio, cohere
# Successfully installed aiofiles-23.2.1 boto3-1.35.25 botocore-1.35.25 cohere-5.9.4 fastapi-0.115.0 fastavro-1.9.7 ffmpy-0.4.0 gradio-4.44.0 gradio-client-1.3.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 httpx-sse-0.4.0 jmespath-1.0.1 orjson-3.10.7 parameterized-0.9.0 pydub-0.25.1 python-multipart-0.0.10 ruff-0.6.7 s3transfer-0.10.2 semantic-version-2.10.0 starlette-0.38.6 tomlkit-0.12.0 types-requests-2.32.0.20240914 uvicorn-0.30.6 websockets-12.0

# %%
# Save as Parquet
mols.to_parquet("/content/chembl_approved_drugs.parquet", index=False)

# %%
import pandas as pd

# Read the Parquet file
df = pd.read_parquet('/content/chembl_approved_drugs.parquet')

# Convert to CSV
df.to_csv('output_file.csv', index=False)

# %%
import pandas as pd
import datamol as dm
import gradio as gr
import cohere
from chembl_webresource_client.new_client import new_client as client
from rdkit import Chem
from rdkit.Chem import Draw

# Set up Cohere API
cohere_api_key = "OIgOnN9bV378w7IJyp68yTYH7XiGs3PpqJAKAhbI"
co = cohere.Client(cohere_api_key)

# Define the columns of interest
columns = ["molecule_chembl_id", "pref_name", "first_approval", "molecule_structures", "molecule_type"]

# Function to fetch molecule data by ChEMBL ID or SMILES
def fetch_molecule_data(chembl_id=None, smiles=None):
    print(f"Received ChEMBL ID: {chembl_id}, SMILES: {smiles}")
    mols = []
    if chembl_id:
        mols = client.molecule.filter(molecule_chembl_id=chembl_id).only(columns)
    elif smiles:
        mols = client.molecule.filter(molecule_structures__canonical_smiles=smiles).only(columns)

    print(f"Retrieved Molecule Data: {mols}")

    if len(mols) == 1:
        mol = mols[0]
        print(f"Fetched Molecule: {mol}")
        return mol.get("pref_name", "Name not found"), mol
    return "Name not found", None

# Function to query Cohere for detailed drug target information
def get_drug_target_info(chembl_id, smiles, pref_name):
    prompt = f"""
    You are an expert in drug discovery. Based on the following information:
    - ChEMBL ID: {chembl_id}
    - SMILES: {smiles}
    - Preferred Name: {pref_name}

    Provide a detailed summary of the drug's known biological targets and its mechanism of action.
    Provide approaches towards the synthesis of new compounds approaching novel drugs for multi targets, give chemical and physical properties of the drug as well.
    Provide target protein structures and formulas for the drug.
    """

    response = co.generate(
        model="command",
        prompt=prompt,
        max_tokens=300,
        temperature=0.5,
        stop_sequences=["--"]
    )
    return response.generations[0].text.strip()

# Function to generate molecular structure image
def generate_structure(smiles):
    if smiles:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            img = Draw.MolToImage(mol)
            return img
    return None

# Gradio function that integrates the molecule retrieval and Cohere integration
def gradio_interface(chembl_id, smiles):
    # Fetch molecule data
    pref_name, mol_data = fetch_molecule_data(chembl_id=chembl_id, smiles=smiles)

    if mol_data:
        # Get drug target information using Cohere
        drug_info = get_drug_target_info(chembl_id, smiles, pref_name)
        # Generate molecular structure image
        structure_img = generate_structure(smiles)
        return pref_name, drug_info, structure_img
    else:
        return "No data found", "No target information available.", None

# Create Gradio interface
iface = gr.Interface(
    fn=gradio_interface,
    inputs=[gr.Textbox(label="ChEMBL ID"), gr.Textbox(label="SMILES")],
    outputs=[gr.Textbox(label="Preferred Name"), gr.Textbox(label="Drug Target Information"), gr.Image(label="Molecular Structure")],
    title="DRUG__DISCOVER",
    description="This app retrieves the preferred name, provides detailed drug target information using the Cohere API, and shows the molecular structure based on the target compund."
)

# Launch the app
iface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://b4d5481265c3e22a7a.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b4d5481265c3e22a7a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
